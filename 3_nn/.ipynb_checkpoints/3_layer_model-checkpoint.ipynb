# %%
#Importing Dependencies

import os
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_tuner as kt

# %%
# Set random seed

seed = 29
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Get Dataset

df = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/stock_prices.csv")
df
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 0        20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0
# 1        20170104_1332  2017-01-04            1332   568.0   576.0   563.0
# 2        20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0
# 3        20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0
# 4        20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0
# ...                ...         ...             ...     ...     ...     ...
# 2332526  20211203_9990  2021-12-03            9990   514.0   528.0   513.0
# 2332527  20211203_9991  2021-12-03            9991   782.0   794.0   782.0
# 2332528  20211203_9993  2021-12-03            9993  1690.0  1690.0  1645.0
# 2332529  20211203_9994  2021-12-03            9994  2388.0  2396.0  2380.0
# 2332530  20211203_9997  2021-12-03            9997   690.0   711.0   686.0
#
#           Close   Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# 0        2742.0    31400               1.0               NaN            False
# 1         571.0  2798500               1.0               NaN            False
# 2        3210.0   270800               1.0               NaN            False
# 3        1550.0    11300               1.0               NaN            False
# 4        3330.0   150800               1.0               NaN            False
# ...         ...      ...               ...               ...              ...
# 2332526   528.0    44200               1.0               NaN            False
# 2332527   794.0    35900               1.0               NaN            False
# 2332528  1645.0     7200               1.0               NaN            False
# 2332529  2389.0     6500               1.0               NaN            False
# 2332530   696.0   381100               1.0               NaN            False
#
#            Target
# 0        0.000730
# 1        0.012324
# 2        0.006154
# 3        0.011053
# 4        0.003026
# ...           ...
# 2332526  0.034816
# 2332527  0.025478
# 2332528 -0.004302
# 2332529  0.009098
# 2332530  0.018414
#
# [2332531 rows x 12 columns]

# %%
# Spliting the data into Training and Validation Set
# Everything from 2021 will be used for validation
# Everything older will be used for training

df_train = df[df['Date'] < '2021-01-01'].copy()
df_train.shape
# Out:
# (1880531, 12)

# %%
df_valid = df[df['Date'] >= '2021-01-01'].copy()
df_valid.shape
# Out:
# (452000, 12)

# %%
# Using about 20% for validation

print("Precent validation: {}".format(df_valid.shape[0] / df.shape[0] * 100))
# Out:
# Precent validation: 19.37809186673189

# %%
num_features = ['Open', 'High', 'Low', 'Close', 'Volume']
target = ['Target']
df_train = df_train[num_features + target].reset_index(drop=True).copy()
df_valid = df_valid[num_features + target].reset_index(drop=True).copy()
df_train.dropna(subset=num_features + target, axis=0, inplace=True)
df_valid.dropna(subset=num_features + target, axis=0, inplace=True)
df_valid.head()
# Out:
#      Open    High     Low   Close   Volume    Target
# 0  2951.0  2951.0  2913.0  2950.0     9700  0.011502
# 1   428.0   429.0   416.0   421.0  1780500  0.019093
# 2  2229.0  2231.0  2179.0  2202.0   112400  0.015075
# 3  1701.0  1701.0  1672.0  1674.0    67900 -0.003503
# 4  1597.0  1597.0  1577.0  1588.0     4500 -0.012033

# %%
# Define encoding function for numerical features
def encode_numerical_feature(feature, name, dataset):
    # Create a Normalization layer for our feature
    normalizer = layers.Normalization()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    encoded_feature = normalizer(feature)
    return encoded_feature

# %%
# Generate tensorflow dataset
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("Target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

train_ds = dataframe_to_dataset(df_train)
valid_ds = dataframe_to_dataset(df_valid)

# %%
# Batch the dataset
train_ds = train_ds.batch(1024)
valid_ds = valid_ds.batch(1024)

# %%
# %%time
# Raw numerical features
Open = keras.Input(shape=(1,), name="Open")
High = keras.Input(shape=(1,), name="High")
Low = keras.Input(shape=(1,), name="Low")
Close = keras.Input(shape=(1,), name="Close")
Volume = keras.Input(shape=(1,), name="Volume")

all_inputs = [Open, High, Low, Close, Volume]

# Encode numerical features
open_encoded = encode_numerical_feature(Open, "Open", train_ds)
high_encoded = encode_numerical_feature(High, "High", train_ds)
low_encoded = encode_numerical_feature(Low, "Low", train_ds)
close_encoded = encode_numerical_feature(Close, "Close", train_ds)
volume_encoded = encode_numerical_feature(Volume, "Volume", train_ds)
# Out:
# CPU times: total: 1min 7s
# Wall time: 59.5 s

# %%
# building a model using a model builder function
def model_builder(hp):
    """
    Build model for hyperparameters tuning
    
    hp: HyperParameters class instance
    """
    
    # defining a set of hyperparametrs for tuning and a range of values for each

    
    
    # building a model
    inputs = tf.keras.Input(shape=(None,5))
    x = layers.Dense(units=hp.Int("units", min_value=32, max_value=512, step=32),activation="relu",)(inputs)
    outputs = layers.Dense(1, activation="linear")(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    # model compilation
    model.compile(
            optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"],
    )
    
    return model

# %%
# tuner initialization
tuner = kt.Hyperband(hypermodel = model_builder,
                     objective = kt.Objective("val_f1", direction="max"),
                     max_epochs = 20,
					 project_name='hyperband_tuner')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\hyperband_tuner\oracle.json

# %%
tuner.search(list(train_ds.values()), epochs=2, validation_data=valid_ds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 tuner.search(list(train_ds.values()), epochs=2, validation_data=valid_ds)
#
# AttributeError: 'BatchDataset' object has no attribute 'values'

# %%
# Concat all features of input layer
all_features = layers.concatenate(
    [
        open_encoded,
        high_encoded,
        low_encoded,
        close_encoded,
        volume_encoded,
    ]
)

# Add several hidden layers with batch_norm and dropout
x = layers.Dense(256, activation="relu")(all_features)


# Output layer for regression task
output = layers.Dense(1, activation="linear")(x)

# Create our NN model
model = keras.Model(all_inputs, output)
model.compile("adam", "mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.fit(train_ds, epochs=50, validation_data=valid_ds)
# Out:
# Epoch 1/50
# 1831/1831 [==============================] - 23s 10ms/step - loss: 5.9248e-04 - root_mean_squared_error: 0.0243 - val_loss: 6.4800e-04 - val_root_mean_squared_error: 0.0255
# Epoch 2/50
# 1831/1831 [==============================] - 30s 13ms/step - loss: 6.0401e-04 - root_mean_squared_error: 0.0246 - val_loss: 4.9262e-04 - val_root_mean_squared_error: 0.0222
# Epoch 3/50
# 1831/1831 [==============================] - 33s 14ms/step - loss: 5.9100e-04 - root_mean_squared_error: 0.0243 - val_loss: 5.0188e-04 - val_root_mean_squared_error: 0.0224
# Epoch 4/50
# 1831/1831 [==============================] - 36s 15ms/step - loss: 5.8488e-04 - root_mean_squared_error: 0.0242 - val_loss: 4.8639e-04 - val_root_mean_squared_error: 0.0221
# Epoch 5/50
# 1831/1831 [==============================] - 36s 15ms/step - loss: 5.8208e-04 - root_mean_squared_error: 0.0241 - val_loss: 5.2509e-04 - val_root_mean_squared_error: 0.0229
# Epoch 6/50
# 1831/1831 [==============================] - 37s 15ms/step - loss: 5.8078e-04 - root_mean_squared_error: 0.0241 - val_loss: 5.3053e-04 - val_root_mean_squared_error: 0.0230
# Epoch 7/50
# 1831/1831 [==============================] - 37s 15ms/step - loss: 5.7933e-04 - root_mean_squared_error: 0.0241 - val_loss: 4.9306e-04 - val_root_mean_squared_error: 0.0222
# Epoch 8/50
# 1831/1831 [==============================] - 38s 16ms/step - loss: 5.7194e-04 - root_mean_squared_error: 0.0239 - val_loss: 4.8701e-04 - val_root_mean_squared_error: 0.0221
# Epoch 9/50
# 1831/1831 [==============================] - 38s 16ms/step - loss: 5.6986e-04 - root_mean_squared_error: 0.0239 - val_loss: 4.9705e-04 - val_root_mean_squared_error: 0.0223
# Epoch 10/50
# 1831/1831 [==============================] - 40s 17ms/step - loss: 5.7039e-04 - root_mean_squared_error: 0.0239 - val_loss: 4.8556e-04 - val_root_mean_squared_error: 0.0220
# Epoch 11/50
# 1831/1831 [==============================] - 39s 16ms/step - loss: 5.6734e-04 - root_mean_squared_error: 0.0238 - val_loss: 5.0402e-04 - val_root_mean_squared_error: 0.0225
# Epoch 12/50
# 1831/1831 [==============================] - 39s 16ms/step - loss: 5.6611e-04 - root_mean_squared_error: 0.0238 - val_loss: 4.9031e-04 - val_root_mean_squared_error: 0.0221
# Epoch 13/50
# 1831/1831 [==============================] - 39s 16ms/step - loss: 5.6481e-04 - root_mean_squared_error: 0.0238 - val_loss: 4.9728e-04 - val_root_mean_squared_error: 0.0223
# Epoch 14/50
# 1831/1831 [==============================] - 39s 16ms/step - loss: 5.6432e-04 - root_mean_squared_error: 0.0238 - val_loss: 4.8319e-04 - val_root_mean_squared_error: 0.0220
# Epoch 15/50
# 1831/1831 [==============================] - 39s 16ms/step - loss: 5.6386e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8330e-04 - val_root_mean_squared_error: 0.0220
# Epoch 16/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6357e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8310e-04 - val_root_mean_squared_error: 0.0220
# Epoch 17/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6322e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8529e-04 - val_root_mean_squared_error: 0.0220
# Epoch 18/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6315e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8297e-04 - val_root_mean_squared_error: 0.0220
# Epoch 19/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6301e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8315e-04 - val_root_mean_squared_error: 0.0220
# Epoch 20/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6297e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8261e-04 - val_root_mean_squared_error: 0.0220
# Epoch 21/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6295e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8269e-04 - val_root_mean_squared_error: 0.0220
# Epoch 22/50
# 1831/1831 [==============================] - 41s 17ms/step - loss: 5.6297e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8269e-04 - val_root_mean_squared_error: 0.0220
# Epoch 23/50
# 1831/1831 [==============================] - 41s 17ms/step - loss: 5.6297e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8264e-04 - val_root_mean_squared_error: 0.0220
# Epoch 24/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6299e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8263e-04 - val_root_mean_squared_error: 0.0220
# Epoch 25/50
# 1831/1831 [==============================] - 41s 17ms/step - loss: 5.6296e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8271e-04 - val_root_mean_squared_error: 0.0220
# Epoch 26/50
# 1831/1831 [==============================] - 41s 17ms/step - loss: 5.6295e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8276e-04 - val_root_mean_squared_error: 0.0220
# Epoch 27/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6295e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8266e-04 - val_root_mean_squared_error: 0.0220
# Epoch 28/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6293e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8280e-04 - val_root_mean_squared_error: 0.0220
# Epoch 29/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6297e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8276e-04 - val_root_mean_squared_error: 0.0220
# Epoch 30/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6292e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8262e-04 - val_root_mean_squared_error: 0.0220
# Epoch 31/50
# 1831/1831 [==============================] - 42s 17ms/step - loss: 5.6295e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8457e-04 - val_root_mean_squared_error: 0.0220
# Epoch 32/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6298e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8274e-04 - val_root_mean_squared_error: 0.0220
# Epoch 33/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6295e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8359e-04 - val_root_mean_squared_error: 0.0220
# Epoch 34/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6296e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8270e-04 - val_root_mean_squared_error: 0.0220
# Epoch 35/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6293e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8264e-04 - val_root_mean_squared_error: 0.0220
# Epoch 36/50
# 1831/1831 [==============================] - 40s 16ms/step - loss: 5.6296e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8268e-04 - val_root_mean_squared_error: 0.0220
# Epoch 37/50
# 1831/1831 [==============================] - 41s 16ms/step - loss: 5.6297e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8280e-04 - val_root_mean_squared_error: 0.0220
# Epoch 38/50
# 1831/1831 [==============================] - 44s 18ms/step - loss: 5.6300e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8322e-04 - val_root_mean_squared_error: 0.0220
# Epoch 39/50
# 1831/1831 [==============================] - 43s 17ms/step - loss: 5.6298e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.8317e-04 - val_root_mean_squared_error: 0.0220
# Epoch 40/50
# 1831/1831 [==============================] - ETA: 0s - loss: 5.6292e-04 - root_mean_squared_error: 0.0237

# %%
# Save model
model.save("model.h5")
